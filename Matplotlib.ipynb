# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
x=np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel("X Axis Name")
plt.ylabel("Y Axis Name")
plt.title('Graph Between X and Y')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y,'r')
axes.set_xlabel("X Axis")
axes.set_ylabel("Y axis")
axes.set_title("X Axis VS Y Axis")
#axes.plot()
# Out:
# Text(0.5, 1.0, 'X Axis VS Y Axis')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'r')
axes1.set_xlabel("X Axis")
axes1.set_ylabel("Y axis")
axes1.set_title("X Axis VS Y Axis")

axes2.plot(y,x,'b')
axes2.set_xlabel("X Axis")
axes2.set_ylabel("Y axis")
axes2.set_title("Y Axis VS X Axis")
# Out:
# Text(0.5, 1.0, 'Y Axis VS X Axis')

# %%
fig,axes=plt.subplots(nrows=1,ncols=4)

# %%
fig

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,'r')
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_title("This Is Title")
fig.tight_layout()
fig

# %%
fig=plt.figure(figsize=(8,4),dpi=100)

# %%
fig,axes=plt.subplots(figsize=(8,4),dpi=100)
axes.plot(x,y,'r')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title("This Is Title")
# Out:
# Text(0.5, 1.0, 'This Is Title')

# %%
#saving Graph
fig.savefig('Thursday.png')
